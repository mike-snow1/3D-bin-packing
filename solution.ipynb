# %%
from OptimalPackingFinder import OptimalPackingFinder

# %%
items_example = {
    'item_1': {'item_no': 1, 'width': 6, 'height': 1, 'depth': 3, 'weight': 0},
    'item_2': {'item_no': 2, 'width': 30, 'height': 9, 'depth': 5, 'weight': 0},
    'item_3': {'item_no': 3, 'width': 10, 'height': 11, 'depth': 24, 'weight': 0},
    'item_4': {'item_no': 4, 'width': 12, 'height': 3, 'depth': 6, 'weight': 0},
    'item_5': {'item_no': 5, 'width': 28, 'height': 6, 'depth': 20, 'weight': 0},
}

optimal_packer = OptimalPackingFinder(items_example, reduction_factor=0.1)
optimal_packer.find_optimal_bin_dimensions()
print(f"Optimal bin dimensions (WxHxD): {optimal_packer.optimal_dimensions}")
optimal_packer.visualize_packing()
# Out:
# Initial estimate: (86, 30, 58)
# Reducing dimensions to: (8.6, 3.0, 5.800000000000001)
# Found optimal dimensions (previous iteration): (85.99999999999999, 30.0, 58.00000000000001)
# Optimal bin dimensions (WxHxD): (85.99999999999999, 30.0, 58.00000000000001)

# %%
optimal_packer.optimal_dimensions
# Out:
# (55.896086918774216, 15.404433402811792, 44.012666865176534)

# %%
items_example = {
 'item_1': {'item_no': 1, 'width': 13, 'height': 22, 'depth': 9, 'weight': 0},
 'item_2': {'item_no': 2, 'width': 16, 'height': 30, 'depth': 11, 'weight': 0},
 'item_3': {'item_no': 3, 'width': 27, 'height': 29, 'depth': 18, 'weight': 0},
 'item_4': {'item_no': 4, 'width': 18, 'height': 5, 'depth': 24, 'weight': 0},
 'item_5': {'item_no': 5, 'width': 15, 'height': 25, 'depth': 8, 'weight': 0},
 'item_6': {'item_no': 6, 'width': 11, 'height': 21, 'depth': 27, 'weight': 0},
 'item_7': {'item_no': 7, 'width': 27, 'height': 8, 'depth': 10, 'weight': 0},
 'item_8': {'item_no': 8, 'width': 7, 'height': 25, 'depth': 5, 'weight': 0},
 'item_9': {'item_no': 9, 'width': 14, 'height': 30, 'depth': 9, 'weight': 0},
 'item_10': {'item_no': 10, 'width': 25, 'height': 5, 'depth': 10, 'weight': 0}
}

optimal_packer = OptimalPackingFinder(items_example, reduction_factor=0.99)
optimal_packer.find_optimal_bin_dimensions()
print(f"Optimal bin dimensions (WxHxD): {optimal_packer.optimal_dimensions}")
optimal_packer.visualize_packing()
# Out:
# Initial estimate: (173, 200, 131)
# Reducing dimensions to: (171.27, 198.0, 129.69)
# Reducing dimensions to: (169.5573, 196.02, 128.3931)
# Reducing dimensions to: (167.861727, 194.0598, 127.10916900000001)
# Reducing dimensions to: (166.18310973, 192.119202, 125.83807731)
# Reducing dimensions to: (164.52127863270002, 190.19800998, 124.5796965369)
# Reducing dimensions to: (162.87606584637302, 188.2960298802, 123.333899571531)
# Reducing dimensions to: (161.2473051879093, 186.413069581398, 122.10056057581569)
# Reducing dimensions to: (159.63483213603018, 184.54893888558402, 120.87955497005754)
# Reducing dimensions to: (158.0384838146699, 182.70344949672818, 119.67075942035696)
# Reducing dimensions to: (156.4580989765232, 180.8764150017609, 118.47405182615339)
# Reducing dimensions to: (154.89351798675796, 179.06765085174328, 117.28931130789185)
# Reducing dimensions to: (153.34458280689037, 177.27697434322585, 116.11641819481294)
# ...

# %%
items_example = {
 'item_1': {'item_no': 1, 'width': 14, 'height': 8, 'depth': 18, 'weight': 0},
 'item_2': {'item_no': 2, 'width': 30, 'height': 15, 'depth': 27, 'weight': 0},
 'item_3': {'item_no': 3, 'width': 13, 'height': 20, 'depth': 12, 'weight': 0},
 'item_4': {'item_no': 4, 'width': 8, 'height': 20, 'depth': 25, 'weight': 0},
 'item_5': {'item_no': 5, 'width': 7, 'height': 30, 'depth': 15, 'weight': 0},
 'item_6': {'item_no': 6, 'width': 22, 'height': 16, 'depth': 29, 'weight': 0},
 'item_7': {'item_no': 7, 'width': 24, 'height': 15, 'depth': 25, 'weight': 0},
 'item_8': {'item_no': 8, 'width': 5, 'height': 11, 'depth': 14, 'weight': 0},
 'item_9': {'item_no': 9, 'width': 8, 'height': 12, 'depth': 25, 'weight': 0},
 'item_10': {'item_no': 10, 'width': 21, 'height': 27, 'depth': 11, 'weight': 0},
 'item_11': {'item_no': 11, 'width': 26, 'height': 29, 'depth': 12, 'weight': 0},
 'item_12': {'item_no': 12, 'width': 21, 'height': 22, 'depth': 20, 'weight': 0},
 'item_13': {'item_no': 13, 'width': 5, 'height': 15, 'depth': 15, 'weight': 0},
 'item_14': {'item_no': 14, 'width': 13, 'height': 19, 'depth': 27, 'weight': 0},
 'item_15': {'item_no': 15, 'width': 10, 'height': 15, 'depth': 29, 'weight': 0},
 'item_16': {'item_no': 16, 'width': 24, 'height': 28, 'depth': 24, 'weight': 0},
 'item_17': {'item_no': 17, 'width': 21, 'height': 25, 'depth': 25, 'weight': 0},
 'item_18': {'item_no': 18, 'width': 10, 'height': 12, 'depth': 23, 'weight': 0},
 'item_19': {'item_no': 19, 'width': 12, 'height': 8, 'depth': 22, 'weight': 0},
 'item_20': {'item_no': 20, 'width': 16, 'height': 25, 'depth': 10, 'weight': 0}
}

optimal_packer = OptimalPackingFinder(items_example, reduction_factor=0.99)
optimal_packer.find_optimal_bin_dimensions()
print(f"Optimal bin dimensions (WxHxD): {optimal_packer.optimal_dimensions}")
optimal_packer.visualize_packing()
# Out:
# Initial estimate: (310, 372, 408)
# Reducing dimensions to: (306.9, 368.28, 403.92)
# Reducing dimensions to: (303.83099999999996, 364.5972, 399.8808)
# Reducing dimensions to: (300.79268999999994, 360.95122799999996, 395.881992)
# Reducing dimensions to: (297.7847630999999, 357.34171571999997, 391.92317208000003)
# Reducing dimensions to: (294.80691546899993, 353.76829856279994, 388.00394035920004)
# Reducing dimensions to: (291.8588463143099, 350.23061557717193, 384.12390095560806)
# Reducing dimensions to: (288.9402578511668, 346.7283094214002, 380.282661946052)
# Reducing dimensions to: (286.0508552726551, 343.2610263271862, 376.47983532659146)
# Reducing dimensions to: (283.1903467199285, 339.82841606391435, 372.71503697332554)
# Reducing dimensions to: (280.3584432527292, 336.4301319032752, 368.9878866035923)
# Reducing dimensions to: (277.5548588202019, 333.06583058424246, 365.29800773755636)
# Reducing dimensions to: (274.7793102319999, 329.73517227840006, 361.6450276601808)
# ...
